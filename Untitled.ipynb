# %%
4*5
# Out:
# 20

# %%
2*2
# Out:
# 4

# %% [markdown]
# This is a text cell markdown
#
# # head1
# ## head2
# ### head3
# #### head4
# ##### head5

# %%
2*7
# Out:
# 14

# %%
3*7
# Out:
# 21

# %%
test

# %%
test
